# %%
# !pip install -q langchain-google-genai langchain-community langchain-core duckduckgo-search

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
import requests

# %%
# !pip install -U ddgs

# %%
# 1. Install the compatibility package first if you haven't
# !pip install -U langchain-classic

# 2. Update your code to use this path
from langchain_classic.agents import AgentExecutor

# %%
# !pip install -U langchainhub

# %%
# !pip install -U langchainhub

# %%
# !pip install -U langchain-hub

# %%
# 1. Install/Upgrade the required package
# !pip install -U langsmith

# 2. Use the LangSmith client to pull the prompt
from langsmith import Client

client = Client()
# The pull_prompt method is the new standard
prompt = client.pull_prompt("hwchase17/react")

print("✅ Prompt successfully pulled from Hub!")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_classic.agents import create_react_agent
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool
import requests
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyBnQmVcmroUaNnBfuiGYhayF-4SLd2xYDk"
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash', api_key=os.environ["GOOGLE_API_KEY"])

search_tool = DuckDuckGoSearchRun()

@tool
def get_weather_data(city: str) -> str:
  """
  This function fetches the current weather data for a given city
  """
  url = f'https://api.weatherstack.com/current?access_key=5f2097ae38b49b2b3f571b319413bedc={city}'

  response = requests.get(url)

  return response.json()

# Step 3: Create the ReAct agent manually with the pulled prompt
agent = create_react_agent(
    llm=llm,
    tools=[search_tool, get_weather_data],
    prompt=prompt
)

# %%
from langchain_classic.agents import AgentExecutor

# Step 4: Wrap it with AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=[search_tool, get_weather_data],
    verbose=True
)

# %%
# Step 5: Invoke
response = agent_executor.invoke({"input": "Find the capital of Madhya Pradesh, then find it's current weather condition"})
print(response)

# %%
response['output']
